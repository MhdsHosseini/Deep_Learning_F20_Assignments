# %% [markdown]
# MH

# %% [markdown]
# Train neural network models (at least two different networks for each dataset, i.e., no. layers, no. neurons, activations, ...) in either Tensorflow or Pytorch to perform regression on the following datasets:
#
# One different dataset, up to your choice: Red Wine Quality

# %%
import tensorflow as tf
from tensorflow import keras
from matplotlib import pyplot
import numpy as np
import pandas as pd
import sklearn
import math
import glob
import os
import sys
print("imported!")
# Out:
# imported!

# %%
path = "data"

# %% [markdown]
# Importing:

# %%
wine1 = pd.read_excel(path+'/wine1.xls')
wine2 = pd.read_excel(path+'/win2.xls')

# %% [markdown]
# Let's view some of the data:

# %%
wine1.shape
# Out:
# (246, 12)

# %%
wine1.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
wine1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 12 columns):
# fixed acidity           246 non-null float64
# volatile acidity        246 non-null float64
# citric acid             246 non-null float64
# residual sugar          246 non-null float64
# chlorides               246 non-null float64
# free sulfur dioxide     246 non-null float64
# total sulfur dioxide    246 non-null float64
# density                 246 non-null float64
# pH                      246 non-null float64
# sulphates               246 non-null float64
# alcohol                 246 non-null float64
# quality                 246 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 23.2 KB

# %%
wine2.shape
# Out:
# (130, 12)

# %%
wine2.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.2              0.23         0.39            14.2      0.058
# 1            7.2              0.23         0.39            14.2      0.058
# 2            7.2              0.23         0.39            14.2      0.058
# 3            5.9              0.15         0.31             5.8      0.041
# 4            7.4              0.28         0.42            19.8      0.066
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 49.0                   192   0.9979  2.98       0.48
# 1                 49.0                   192   0.9979  2.98       0.48
# 2                 49.0                   192   0.9979  2.98       0.48
# 3                 53.0                   155   0.9945  3.52       0.46
# 4                 53.0                   195   1.0000  2.96       0.44
#
#    alcohol  quality
# 0      9.0        7
# 1      9.0        7
# 2      9.0        7
# 3     10.5        6
# 4      9.1        5

# %%
wine2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 12 columns):
# fixed acidity           130 non-null float64
# volatile acidity        130 non-null float64
# citric acid             130 non-null float64
# residual sugar          130 non-null float64
# chlorides               130 non-null float64
# free sulfur dioxide     130 non-null float64
# total sulfur dioxide    130 non-null int64
# density                 130 non-null float64
# pH                      130 non-null float64
# sulphates               130 non-null float64
# alcohol                 130 non-null float64
# quality                 130 non-null int64
# dtypes: float64(10), int64(2)
# memory usage: 12.3 KB

# %% [markdown]
# The data seems to be compatible. Let's merge them:

# %%
wine=wine1.merge(wine2, how='outer')
# Out:
# C:\Users\Mahdis\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py:1089: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   UserWarning,

# %%
wine.shape
# Out:
# (376, 12)

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            7.0              0.27         0.36            20.7      0.045
# 2            6.3              0.30         0.34             1.6      0.049
# 3            6.3              0.30         0.34             1.6      0.049
# 4            8.1              0.28         0.40             6.9      0.050
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 45.0                 170.0   1.0010  3.00       0.45
# 2                 14.0                 132.0   0.9940  3.30       0.49
# 3                 14.0                 132.0   0.9940  3.30       0.49
# 4                 30.0                  97.0   0.9951  3.26       0.44
#
#    alcohol  quality
# 0      8.8        6
# 1      8.8        6
# 2      9.5        6
# 3      9.5        6
# 4     10.1        6

# %% [markdown]
# We have to prepare the data before doing any statistical analysis on it:

# %% [markdown]
# First let's search for the missing values.
# If the missing values are low, we can ignore them and remove them from the dataset.
# Else, if they are high, we can entirely ignore the column having so many NaNs.

# %%
print(wine.isnull().sum())
# wine = wine.dropna(axis=0)
# print(wine.isnull().sum())
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# Not much, we can just remove them.

# %% [markdown]
# Now we'll check for other anomalies in the data:

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 376 entries, 0 to 375
# Data columns (total 12 columns):
# fixed acidity           376 non-null float64
# volatile acidity        376 non-null float64
# citric acid             376 non-null float64
# residual sugar          376 non-null float64
# chlorides               376 non-null float64
# free sulfur dioxide     376 non-null float64
# total sulfur dioxide    376 non-null float64
# density                 376 non-null float64
# pH                      376 non-null float64
# sulphates               376 non-null float64
# alcohol                 376 non-null float64
# quality                 376 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 38.2 KB

# %% [markdown]
# Hmmm, it seems we have no non-numerical columns here.
#
# Let's search for outliers: (Warning! Long output.)

# %%
for col in wine.columns:
    print(wine[col].value_counts())
# Out:
# 6.8     36
# 7.2     31
# 7.1     26
# 6.4     21
# 7.3     20
# 6.3     18
# 6.7     18
# 7.4     18
# 6.9     17
# 7.0     16
# 6.2     15
# 6.1     14
# 6.6     14
# 6.0     13
# 6.5     11
# 7.5     10
# 5.8      8
# 5.9      7
# 8.1      6
# 8.3      6
# 8.2      5
# 7.9      5
# 7.6      4
# 5.7      4
# 5.6      4
# 5.1      3
# 8.6      3
# 7.8      3
# 7.7      3
# 5.0      2
# 5.5      2
# 5.2      2
# 8.5      2
# 9.8      2
# 5.4      2
# 10.2     1
# 8.4      1
# 10.0     1
# 8.0      1
# 9.1      1
# Name: fixed acidity, dtype: int64
# 0.240    29
# 0.230    26
# 0.270    26
# 0.280    25
# 0.250    20
#          ..
# 0.590     1
# 0.255     1
# 0.905     1
# 0.245     1
# 0.640     1
# Name: volatile acidity, Length: 62, dtype: int64
# 0.32    23
# 0.40    22
# 0.34    19
# 0.36    19
# 0.24    19
# 0.39    18
# 0.35    17
# 0.31    16
# 0.27    13
# 0.42    11
# 0.41    11
# 0.26    11
# 0.38    11
# 0.30    11
# 0.37     9
# 0.28     9
# 0.46     8
# 0.22     7
# 0.48     7
# 0.43     7
# 0.56     7
# 0.33     7
# 0.21     7
# 0.25     6
# 0.23     6
# 0.44     6
# 0.29     6
# 0.14     5
# 0.47     5
# 0.50     5
# 0.04     4
# 0.15     4
# 0.62     3
# 0.00     3
# 0.07     3
# 0.45     3
# 0.51     3
# 0.67     2
# 0.63     2
# 0.66     2
# 0.12     2
# 0.59     2
# 0.20     2
# 0.61     2
# 0.18     1
# 0.16     1
# 0.13     1
# 0.88     1
# 0.10     1
# 0.70     1
# 0.08     1
# 0.54     1
# 0.19     1
# 0.60     1
# 0.03     1
# Name: citric acid, dtype: int64
# 1.2     20
# 1.5     19
# 1.4     17
# 1.1     13
# 1.6     10
#         ..
# 7.3      1
# 10.3     1
# 9.9      1
# 15.6     1
# 11.6     1
# Name: residual sugar, Length: 141, dtype: int64
# 0.044    25
# 0.040    19
# 0.050    19
# 0.045    19
# 0.038    17
# 0.046    16
# 0.049    16
# 0.058    14
# 0.048    14
# 0.036    14
# 0.031    13
# 0.047    10
# 0.041     9
# 0.037     9
# 0.034     8
# 0.043     8
# 0.051     8
# 0.063     8
# 0.052     8
# 0.054     8
# 0.035     8
# 0.066     7
# 0.057     7
# 0.032     7
# 0.053     7
# 0.060     6
# 0.033     6
# 0.055     6
# 0.039     5
# 0.042     5
# 0.027     5
# 0.030     4
# 0.056     4
# 0.029     3
# 0.069     3
# 0.026     3
# 0.064     2
# 0.197     2
# 0.059     2
# 0.092     2
# 0.062     2
# 0.070     1
# 0.074     1
# 0.172     1
# 0.020     1
# 0.067     1
# 0.028     1
# 0.068     1
# 0.082     1
# 0.132     1
# 0.147     1
# 0.065     1
# 0.200     1
# 0.089     1
# 0.080     1
# 0.061     1
# 0.021     1
# 0.173     1
# 0.071     1
# Name: chlorides, dtype: int64
# 30.0    15
# 55.0    15
# 48.0    14
# 38.0    13
# 29.0    10
#         ..
# 5.0      1
# 61.0     1
# 76.0     1
# 50.5     1
# 81.0     1
# Name: free sulfur dioxide, Length: 75, dtype: int64
# 155.0    9
# 170.0    7
# 152.0    7
# 164.0    7
# 168.0    6
#         ..
# 57.0     1
# 241.0    1
# 188.0    1
# 121.0    1
# 313.0    1
# Name: total sulfur dioxide, Length: 152, dtype: int64
# 0.9979    15
# 0.9927    14
# 0.9934    14
# 0.9920    12
# 0.9917    10
#           ..
# 0.9933     1
# 0.9921     1
# 0.9948     1
# 1.0002     1
# 0.9993     1
# Name: density, Length: 86, dtype: int64
# 3.19    17
# 3.09    15
# 3.15    14
# 3.12    13
# 3.20    13
#         ..
# 3.61     1
# 3.06     1
# 3.07     1
# 3.43     1
# 3.53     1
# Name: pH, Length: 66, dtype: int64
# 0.44    28
# 0.50    24
# 0.38    21
# 0.39    20
# 0.51    19
# 0.42    17
# 0.46    17
# 0.41    14
# 0.54    13
# 0.47    13
# 0.45    11
# 0.36    11
# 0.53    10
# 0.52    10
# 0.40     9
# 0.37     9
# 0.64     8
# 0.56     8
# 0.49     8
# 0.34     7
# 0.35     7
# 0.43     7
# 0.48     7
# 0.59     7
# 0.57     6
# 0.33     6
# 0.60     6
# 0.55     5
# 0.61     4
# 0.63     4
# 0.58     4
# 0.71     4
# 0.79     3
# 0.30     3
# 0.66     3
# 0.67     3
# 0.29     2
# 0.65     2
# 0.77     2
# 0.32     2
# 0.62     2
# 0.74     2
# 0.68     1
# 0.27     1
# 0.28     1
# 0.76     1
# 0.84     1
# 0.78     1
# 0.75     1
# 0.85     1
# Name: sulphates, dtype: int64
# 10.0    25
# 9.0     22
# 9.1     20
# 9.4     17
# 9.6     17
# 8.7     16
# 9.7     15
# 9.2     15
# 11.4    13
# 8.9     13
# 9.5     13
# 10.2    12
# 10.5    12
# 10.4    12
# 8.8     12
# 9.8     11
# 11.0    10
# 9.9     10
# 9.3     10
# 10.6    10
# 10.8     9
# 11.2     6
# 12.6     6
# 10.1     6
# 10.3     5
# 10.9     5
# 11.5     5
# 12.5     5
# 11.8     4
# 12.0     4
# 11.3     4
# 12.8     4
# 11.1     4
# 12.7     3
# 10.7     3
# 12.4     3
# 8.6      3
# 11.7     2
# 11.6     2
# 12.1     2
# 12.3     2
# 11.9     2
# 8.5      1
# 12.2     1
# Name: alcohol, dtype: int64
# 6    172
# 5    124
# 7     58
# 4     11
# 8     10
# 3      1
# Name: quality, dtype: int64

# %% [markdown]
# We can remove those values with low frequencies:

# %%
# threshold = 1 # Anything that occurs less than this will be removed.
# print(len(wine.index))
# for col in wine.columns:
#     print("\nCleaning:", col)
#     value_counts = wine[col].value_counts()
#     # wine.drop(wine[wine[col].isin(value_counts[value_counts <= threshold].index)].index, inplace=True) # acts reversed
#     to_remove = value_counts[value_counts <= threshold].index
#     wine[col].replace(to_remove, np.nan, inplace=True)
# wine = wine.dropna(axis=0)
# print(len(wine.index))

# %% [markdown]
# Now let see some histograms:

# %%
wine.hist(bins=50,figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000016B94529108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016B94433448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016B9655B548>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000016B96594608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016B965CC708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016B96605848>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000016B9663D708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016B96674808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016B96681408>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000016B966B8608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016B9671C9C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000016B96755A88>]],
#       dtype=object)

# %% [markdown]
# Histograms where skewed too much to a side means the existance of some outliers on the opposite side.

# %% [markdown]
# But we need more data to choose some **variables** as the **target** for our regressor to predict these variables for us.
#
# Let's start with some scatter plots:

# %% [markdown]
# First convert to fully numerical dataframe:

# %%
wine_numerical = wine # .drop('some_categorical_col', axis=1)

# %%
c = pd.plotting.scatter_matrix(wine_numerical, alpha=0.2, figsize=(17, 17))
c;

# %% [markdown]
# We can see that there are good realtionships between some of the variables, for example residual_sugar vs density and alcohol vs density.
# However, these variables are not a very useful to us. So we choose quality and we're going to find a regressor for it with all other variables.
# Also, there is something worth mentioning. As the alcohol of the wine increases, the overall logistic quality seems to increase. We can investigate t later.

# %% [markdown]
# First we start splitting the data into variable-target sets:

# %%
# Split into variables and targets):
x = wine_numerical.copy().drop('quality', axis=1)
y = wine_numerical.copy().pop('quality')

# %% [markdown]
# Then, we split into validation and train sets:

# %%
from sklearn.model_selection import train_test_split
x_t, x_v, y_t, y_v = train_test_split(x, y, test_size=0.20, random_state=0)

# %% [markdown]
# We need to predict quality from all other variables:

# %% [markdown]
# Creating the model:

# %%
def build_model1():
    model = keras.Sequential([
        keras.layers.Dense(64, input_shape=[len(x_t.columns),], activation="relu"),
        keras.layers.Dense(128, activation="relu"),
        keras.layers.Dense(256, activation="relu"),
        keras.layers.Dense(1)
    ])

    optimizer = tf.keras.optimizers.RMSprop(0.001, clipnorm=1)

    model.compile(loss='mean_squared_error',
                optimizer=optimizer,
                metrics=['mean_absolute_error',
                         'mean_squared_error'])
    return model

model1 = build_model1()
model1.summary()
# Out:
# WARNING:tensorflow:From c:\program files\python37\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                768
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 42,369
# Trainable params: 42,369
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Training:

# %%
history = model1.fit(x_t, y_t, validation_data=(x_v, y_v), epochs=100)
# Out:
# WARNING:tensorflow:From c:\program files\python37\lib\site-packages\tensorflow_core\python\ops\clip_ops.py:172: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 300 samples, validate on 76 samples
# Epoch 1/100
# 300/300 [==============================] - 0s 613us/sample - loss: 122.2157 - mean_absolute_error: 8.3971 - mean_squared_error: 122.2157 - val_loss: 24.2437 - val_mean_absolute_error: 4.2757 - val_mean_squared_error: 24.2437
# Epoch 2/100
# 300/300 [==============================] - 0s 67us/sample - loss: 19.4693 - mean_absolute_error: 3.9146 - mean_squared_error: 19.4693 - val_loss: 11.9892 - val_mean_absolute_error: 2.9022 - val_mean_squared_error: 11.9892
# Epoch 3/100
# 300/300 [==============================] - 0s 70us/sample - loss: 13.0192 - mean_absolute_error: 3.2027 - mean_squared_error: 13.0192 - val_loss: 7.9170 - val_mean_absolute_error: 2.3271 - val_mean_squared_error: 7.9170
# Epoch 4/100
# 300/300 [==============================] - 0s 70us/sample - loss: 10.2681 - mean_absolute_error: 2.7945 - mean_squared_error: 10.2681 - val_loss: 6.3352 - val_mean_absolute_error: 2.0454 - val_mean_squared_error: 6.3352
# Epoch 5/100
# 300/300 [==============================] - 0s 80us/sample - loss: 9.1474 - mean_absolute_error: 2.6295 - mean_squared_error: 9.1474 - val_loss: 5.8180 - val_mean_absolute_error: 1.9721 - val_mean_squared_error: 5.8180
# Epoch 6/100
# 300/300 [==============================] - 0s 80us/sample - loss: 7.3704 - mean_absolute_error: 2.3317 - mean_squared_error: 7.3704 - val_loss: 4.5604 - val_mean_absolute_error: 1.7037 - val_mean_squared_error: 4.5604
# Epoch 7/100
# 300/300 [==============================] - 0s 80us/sample - loss: 6.0262 - mean_absolute_error: 2.0956 - mean_squared_error: 6.0262 - val_loss: 3.4423 - val_mean_absolute_error: 1.4850 - val_mean_squared_error: 3.4423
# Epoch 8/100
# 300/300 [==============================] - 0s 80us/sample - loss: 5.6688 - mean_absolute_error: 2.0428 - mean_squared_error: 5.6688 - val_loss: 3.4014 - val_mean_absolute_error: 1.4980 - val_mean_squared_error: 3.4014
# Epoch 9/100
# 300/300 [==============================] - 0s 73us/sample - loss: 4.4349 - mean_absolute_error: 1.7719 - mean_squared_error: 4.4349 - val_loss: 3.5438 - val_mean_absolute_error: 1.5497 - val_mean_squared_error: 3.5438
# Epoch 10/100
# 300/300 [==============================] - 0s 73us/sample - loss: 3.8599 - mean_absolute_error: 1.6433 - mean_squared_error: 3.8599 - val_loss: 3.1466 - val_mean_absolute_error: 1.4543 - val_mean_squared_error: 3.1466
# Epoch 11/100
# 300/300 [==============================] - 0s 77us/sample - loss: 3.3974 - mean_absolute_error: 1.5147 - mean_squared_error: 3.3974 - val_loss: 3.0142 - val_mean_absolute_error: 1.4513 - val_mean_squared_error: 3.0142
# Epoch 12/100
# 300/300 [==============================] - 0s 73us/sample - loss: 3.3313 - mean_absolute_error: 1.5177 - mean_squared_error: 3.3313 - val_loss: 2.7783 - val_mean_absolute_error: 1.4198 - val_mean_squared_error: 2.7783
# Epoch 13/100
# 300/300 [==============================] - 0s 80us/sample - loss: 3.3873 - mean_absolute_error: 1.5190 - mean_squared_error: 3.3873 - val_loss: 3.1042 - val_mean_absolute_error: 1.5622 - val_mean_squared_error: 3.1042
# Epoch 14/100
# 300/300 [==============================] - 0s 73us/sample - loss: 3.0681 - mean_absolute_error: 1.4263 - mean_squared_error: 3.0681 - val_loss: 3.0480 - val_mean_absolute_error: 1.5429 - val_mean_squared_error: 3.0480
# Epoch 15/100
# 300/300 [==============================] - 0s 77us/sample - loss: 2.8376 - mean_absolute_error: 1.3753 - mean_squared_error: 2.8376 - val_loss: 2.6692 - val_mean_absolute_error: 1.4104 - val_mean_squared_error: 2.6692
# Epoch 16/100
# 300/300 [==============================] - 0s 73us/sample - loss: 2.5516 - mean_absolute_error: 1.2766 - mean_squared_error: 2.5516 - val_loss: 2.2180 - val_mean_absolute_error: 1.2394 - val_mean_squared_error: 2.2180
# Epoch 17/100
# 300/300 [==============================] - 0s 77us/sample - loss: 2.5728 - mean_absolute_error: 1.3277 - mean_squared_error: 2.5728 - val_loss: 1.9265 - val_mean_absolute_error: 1.1649 - val_mean_squared_error: 1.9265
# Epoch 18/100
# 300/300 [==============================] - 0s 93us/sample - loss: 2.1469 - mean_absolute_error: 1.2195 - mean_squared_error: 2.1469 - val_loss: 1.8415 - val_mean_absolute_error: 1.1805 - val_mean_squared_error: 1.8415
# Epoch 19/100
# 300/300 [==============================] - 0s 90us/sample - loss: 2.0313 - mean_absolute_error: 1.1907 - mean_squared_error: 2.0313 - val_loss: 1.5077 - val_mean_absolute_error: 1.0450 - val_mean_squared_error: 1.5077
# Epoch 20/100
# 300/300 [==============================] - 0s 90us/sample - loss: 2.0144 - mean_absolute_error: 1.1662 - mean_squared_error: 2.0144 - val_loss: 1.4589 - val_mean_absolute_error: 1.0187 - val_mean_squared_error: 1.4589
# Epoch 21/100
# 300/300 [==============================] - 0s 80us/sample - loss: 1.8354 - mean_absolute_error: 1.1187 - mean_squared_error: 1.8354 - val_loss: 1.3733 - val_mean_absolute_error: 0.9801 - val_mean_squared_error: 1.3733
# Epoch 22/100
# 300/300 [==============================] - 0s 80us/sample - loss: 1.7617 - mean_absolute_error: 1.0959 - mean_squared_error: 1.7617 - val_loss: 1.1114 - val_mean_absolute_error: 0.8854 - val_mean_squared_error: 1.1114
# Epoch 23/100
# 300/300 [==============================] - 0s 83us/sample - loss: 1.6785 - mean_absolute_error: 1.0735 - mean_squared_error: 1.6785 - val_loss: 1.0344 - val_mean_absolute_error: 0.8360 - val_mean_squared_error: 1.0344
# Epoch 24/100
# 300/300 [==============================] - 0s 80us/sample - loss: 1.5831 - mean_absolute_error: 0.9957 - mean_squared_error: 1.5831 - val_loss: 0.9932 - val_mean_absolute_error: 0.8013 - val_mean_squared_error: 0.9932
# Epoch 25/100
# 300/300 [==============================] - 0s 73us/sample - loss: 1.5602 - mean_absolute_error: 0.9695 - mean_squared_error: 1.5602 - val_loss: 1.2567 - val_mean_absolute_error: 0.9545 - val_mean_squared_error: 1.2567
# Epoch 26/100
# 300/300 [==============================] - 0s 73us/sample - loss: 1.4537 - mean_absolute_error: 0.9808 - mean_squared_error: 1.4537 - val_loss: 0.5989 - val_mean_absolute_error: 0.6189 - val_mean_squared_error: 0.5989
# Epoch 27/100
# 300/300 [==============================] - 0s 77us/sample - loss: 1.7343 - mean_absolute_error: 1.0431 - mean_squared_error: 1.7343 - val_loss: 1.1274 - val_mean_absolute_error: 0.8783 - val_mean_squared_error: 1.1274
# Epoch 28/100
# 300/300 [==============================] - 0s 87us/sample - loss: 1.2864 - mean_absolute_error: 0.9211 - mean_squared_error: 1.2864 - val_loss: 0.9738 - val_mean_absolute_error: 0.8025 - val_mean_squared_error: 0.9738
# Epoch 29/100
# 300/300 [==============================] - 0s 90us/sample - loss: 1.2730 - mean_absolute_error: 0.9127 - mean_squared_error: 1.2730 - val_loss: 0.9761 - val_mean_absolute_error: 0.8212 - val_mean_squared_error: 0.9761
# Epoch 30/100
# 300/300 [==============================] - 0s 97us/sample - loss: 1.3106 - mean_absolute_error: 0.9070 - mean_squared_error: 1.3106 - val_loss: 1.0727 - val_mean_absolute_error: 0.8716 - val_mean_squared_error: 1.0727
# Epoch 31/100
# 300/300 [==============================] - 0s 83us/sample - loss: 1.4465 - mean_absolute_error: 0.9758 - mean_squared_error: 1.4465 - val_loss: 1.1071 - val_mean_absolute_error: 0.8883 - val_mean_squared_error: 1.1071
# Epoch 32/100
# 300/300 [==============================] - 0s 90us/sample - loss: 1.2920 - mean_absolute_error: 0.9326 - mean_squared_error: 1.2920 - val_loss: 0.8562 - val_mean_absolute_error: 0.7642 - val_mean_squared_error: 0.8562
# Epoch 33/100
# 300/300 [==============================] - 0s 70us/sample - loss: 1.1971 - mean_absolute_error: 0.8778 - mean_squared_error: 1.1971 - val_loss: 0.8476 - val_mean_absolute_error: 0.7644 - val_mean_squared_error: 0.8476
# Epoch 34/100
# 300/300 [==============================] - 0s 67us/sample - loss: 1.2195 - mean_absolute_error: 0.8915 - mean_squared_error: 1.2195 - val_loss: 0.9378 - val_mean_absolute_error: 0.7942 - val_mean_squared_error: 0.9378
# Epoch 35/100
# 300/300 [==============================] - 0s 73us/sample - loss: 1.1986 - mean_absolute_error: 0.8801 - mean_squared_error: 1.1986 - val_loss: 0.7887 - val_mean_absolute_error: 0.7262 - val_mean_squared_error: 0.7887
# Epoch 36/100
# 300/300 [==============================] - 0s 77us/sample - loss: 1.1411 - mean_absolute_error: 0.8620 - mean_squared_error: 1.1411 - val_loss: 0.9119 - val_mean_absolute_error: 0.7794 - val_mean_squared_error: 0.9119
# Epoch 37/100
# 300/300 [==============================] - 0s 87us/sample - loss: 1.0985 - mean_absolute_error: 0.8371 - mean_squared_error: 1.0985 - val_loss: 0.9462 - val_mean_absolute_error: 0.8063 - val_mean_squared_error: 0.9462
# Epoch 38/100
# 300/300 [==============================] - 0s 87us/sample - loss: 1.1024 - mean_absolute_error: 0.8542 - mean_squared_error: 1.1024 - val_loss: 0.8240 - val_mean_absolute_error: 0.7423 - val_mean_squared_error: 0.8240
# Epoch 39/100
# 300/300 [==============================] - 0s 77us/sample - loss: 1.1587 - mean_absolute_error: 0.8671 - mean_squared_error: 1.1587 - val_loss: 0.9008 - val_mean_absolute_error: 0.7896 - val_mean_squared_error: 0.9008
# Epoch 40/100
# 300/300 [==============================] - 0s 77us/sample - loss: 1.1401 - mean_absolute_error: 0.8615 - mean_squared_error: 1.1401 - val_loss: 0.8324 - val_mean_absolute_error: 0.7399 - val_mean_squared_error: 0.8324
# Epoch 41/100
# 300/300 [==============================] - 0s 80us/sample - loss: 1.0528 - mean_absolute_error: 0.8097 - mean_squared_error: 1.0528 - val_loss: 0.7730 - val_mean_absolute_error: 0.7123 - val_mean_squared_error: 0.7730
# Epoch 42/100
# 300/300 [==============================] - 0s 87us/sample - loss: 1.1064 - mean_absolute_error: 0.8472 - mean_squared_error: 1.1064 - val_loss: 1.0390 - val_mean_absolute_error: 0.8451 - val_mean_squared_error: 1.0390
# Epoch 43/100
# 300/300 [==============================] - 0s 67us/sample - loss: 1.1126 - mean_absolute_error: 0.8450 - mean_squared_error: 1.1126 - val_loss: 0.9320 - val_mean_absolute_error: 0.7988 - val_mean_squared_error: 0.9320
# Epoch 44/100
# 300/300 [==============================] - 0s 70us/sample - loss: 1.1329 - mean_absolute_error: 0.8730 - mean_squared_error: 1.1329 - val_loss: 0.9368 - val_mean_absolute_error: 0.8074 - val_mean_squared_error: 0.9368
# Epoch 45/100
# 300/300 [==============================] - 0s 73us/sample - loss: 1.1198 - mean_absolute_error: 0.8576 - mean_squared_error: 1.1198 - val_loss: 1.0031 - val_mean_absolute_error: 0.8255 - val_mean_squared_error: 1.0031
# Epoch 46/100
# 300/300 [==============================] - 0s 73us/sample - loss: 1.0743 - mean_absolute_error: 0.8372 - mean_squared_error: 1.0743 - val_loss: 0.8234 - val_mean_absolute_error: 0.7300 - val_mean_squared_error: 0.8234
# Epoch 47/100
# 300/300 [==============================] - 0s 80us/sample - loss: 1.0130 - mean_absolute_error: 0.8224 - mean_squared_error: 1.0130 - val_loss: 1.1118 - val_mean_absolute_error: 0.8783 - val_mean_squared_error: 1.1118
# Epoch 48/100
# 300/300 [==============================] - 0s 70us/sample - loss: 1.1563 - mean_absolute_error: 0.8668 - mean_squared_error: 1.1563 - val_loss: 0.9717 - val_mean_absolute_error: 0.8118 - val_mean_squared_error: 0.9717
# Epoch 49/100
# 300/300 [==============================] - 0s 93us/sample - loss: 1.0190 - mean_absolute_error: 0.8303 - mean_squared_error: 1.0190 - val_loss: 0.9384 - val_mean_absolute_error: 0.8049 - val_mean_squared_error: 0.9384
# Epoch 50/100
# 300/300 [==============================] - 0s 97us/sample - loss: 1.0323 - mean_absolute_error: 0.8096 - mean_squared_error: 1.0323 - val_loss: 0.8377 - val_mean_absolute_error: 0.7468 - val_mean_squared_error: 0.8377
# Epoch 51/100
# 300/300 [==============================] - 0s 100us/sample - loss: 0.9298 - mean_absolute_error: 0.7671 - mean_squared_error: 0.9298 - val_loss: 0.9140 - val_mean_absolute_error: 0.7899 - val_mean_squared_error: 0.9140
# Epoch 52/100
# 300/300 [==============================] - 0s 87us/sample - loss: 1.0134 - mean_absolute_error: 0.7966 - mean_squared_error: 1.0134 - val_loss: 0.9245 - val_mean_absolute_error: 0.7863 - val_mean_squared_error: 0.9245
# Epoch 53/100
# 300/300 [==============================] - 0s 70us/sample - loss: 1.0535 - mean_absolute_error: 0.8280 - mean_squared_error: 1.0535 - val_loss: 0.7985 - val_mean_absolute_error: 0.7189 - val_mean_squared_error: 0.7985
# Epoch 54/100
# 300/300 [==============================] - 0s 80us/sample - loss: 1.0635 - mean_absolute_error: 0.8526 - mean_squared_error: 1.0635 - val_loss: 0.7695 - val_mean_absolute_error: 0.6801 - val_mean_squared_error: 0.7695
# Epoch 55/100
# 300/300 [==============================] - 0s 77us/sample - loss: 1.0078 - mean_absolute_error: 0.7923 - mean_squared_error: 1.0078 - val_loss: 0.7415 - val_mean_absolute_error: 0.6811 - val_mean_squared_error: 0.7415
# Epoch 56/100
# 300/300 [==============================] - 0s 77us/sample - loss: 1.0333 - mean_absolute_error: 0.8210 - mean_squared_error: 1.0333 - val_loss: 0.8362 - val_mean_absolute_error: 0.7376 - val_mean_squared_error: 0.8362
# Epoch 57/100
# 300/300 [==============================] - 0s 80us/sample - loss: 0.8771 - mean_absolute_error: 0.7276 - mean_squared_error: 0.8771 - val_loss: 0.8221 - val_mean_absolute_error: 0.7293 - val_mean_squared_error: 0.8221
# Epoch 58/100
# 300/300 [==============================] - 0s 77us/sample - loss: 0.9356 - mean_absolute_error: 0.7770 - mean_squared_error: 0.9356 - val_loss: 0.7806 - val_mean_absolute_error: 0.7014 - val_mean_squared_error: 0.7806
# Epoch 59/100
# 300/300 [==============================] - 0s 83us/sample - loss: 1.0023 - mean_absolute_error: 0.7999 - mean_squared_error: 1.0023 - val_loss: 0.7610 - val_mean_absolute_error: 0.6881 - val_mean_squared_error: 0.7610
# Epoch 60/100
# 300/300 [==============================] - 0s 73us/sample - loss: 0.9092 - mean_absolute_error: 0.7602 - mean_squared_error: 0.9092 - val_loss: 0.8125 - val_mean_absolute_error: 0.7169 - val_mean_squared_error: 0.8125
# Epoch 61/100
# 300/300 [==============================] - 0s 77us/sample - loss: 0.8661 - mean_absolute_error: 0.7494 - mean_squared_error: 0.8661 - val_loss: 0.8385 - val_mean_absolute_error: 0.7356 - val_mean_squared_error: 0.8385
# Epoch 62/100
# 300/300 [==============================] - 0s 73us/sample - loss: 0.8658 - mean_absolute_error: 0.7262 - mean_squared_error: 0.8658 - val_loss: 0.8050 - val_mean_absolute_error: 0.7225 - val_mean_squared_error: 0.8050
# Epoch 63/100
# 300/300 [==============================] - 0s 80us/sample - loss: 0.8999 - mean_absolute_error: 0.7533 - mean_squared_error: 0.8999 - val_loss: 0.7560 - val_mean_absolute_error: 0.6957 - val_mean_squared_error: 0.7560
# Epoch 64/100
# 300/300 [==============================] - 0s 73us/sample - loss: 0.9595 - mean_absolute_error: 0.7974 - mean_squared_error: 0.9595 - val_loss: 0.7396 - val_mean_absolute_error: 0.6910 - val_mean_squared_error: 0.7396
# Epoch 65/100
# 300/300 [==============================] - 0s 90us/sample - loss: 0.8691 - mean_absolute_error: 0.7337 - mean_squared_error: 0.8691 - val_loss: 0.7748 - val_mean_absolute_error: 0.6963 - val_mean_squared_error: 0.7748
# Epoch 66/100
# 300/300 [==============================] - 0s 93us/sample - loss: 0.9036 - mean_absolute_error: 0.7734 - mean_squared_error: 0.9036 - val_loss: 0.7837 - val_mean_absolute_error: 0.7031 - val_mean_squared_error: 0.7837
# Epoch 67/100
# 300/300 [==============================] - 0s 87us/sample - loss: 0.8451 - mean_absolute_error: 0.7388 - mean_squared_error: 0.8451 - val_loss: 0.6711 - val_mean_absolute_error: 0.6334 - val_mean_squared_error: 0.6711
# Epoch 68/100
# 300/300 [==============================] - 0s 93us/sample - loss: 0.8467 - mean_absolute_error: 0.7500 - mean_squared_error: 0.8467 - val_loss: 0.7116 - val_mean_absolute_error: 0.6583 - val_mean_squared_error: 0.7116
# Epoch 69/100
# 300/300 [==============================] - 0s 77us/sample - loss: 0.7568 - mean_absolute_error: 0.6791 - mean_squared_error: 0.7568 - val_loss: 0.5352 - val_mean_absolute_error: 0.5749 - val_mean_squared_error: 0.5352
# Epoch 70/100
# 300/300 [==============================] - 0s 80us/sample - loss: 0.8891 - mean_absolute_error: 0.7488 - mean_squared_error: 0.8891 - val_loss: 0.7049 - val_mean_absolute_error: 0.6578 - val_mean_squared_error: 0.7049
# Epoch 71/100
# 300/300 [==============================] - 0s 83us/sample - loss: 0.8207 - mean_absolute_error: 0.7288 - mean_squared_error: 0.8207 - val_loss: 0.6416 - val_mean_absolute_error: 0.6205 - val_mean_squared_error: 0.6416
# Epoch 72/100
# 300/300 [==============================] - 0s 77us/sample - loss: 0.9000 - mean_absolute_error: 0.7606 - mean_squared_error: 0.9000 - val_loss: 0.6467 - val_mean_absolute_error: 0.6227 - val_mean_squared_error: 0.6467
# Epoch 73/100
# 300/300 [==============================] - 0s 83us/sample - loss: 0.7405 - mean_absolute_error: 0.6883 - mean_squared_error: 0.7405 - val_loss: 0.7111 - val_mean_absolute_error: 0.6689 - val_mean_squared_error: 0.7111
# Epoch 74/100
# 300/300 [==============================] - 0s 80us/sample - loss: 0.8073 - mean_absolute_error: 0.7281 - mean_squared_error: 0.8073 - val_loss: 0.7201 - val_mean_absolute_error: 0.6709 - val_mean_squared_error: 0.7201
# Epoch 75/100
# 300/300 [==============================] - 0s 80us/sample - loss: 0.8221 - mean_absolute_error: 0.7479 - mean_squared_error: 0.8221 - val_loss: 0.7179 - val_mean_absolute_error: 0.6916 - val_mean_squared_error: 0.7179
# Epoch 76/100
# 300/300 [==============================] - 0s 73us/sample - loss: 0.7744 - mean_absolute_error: 0.6819 - mean_squared_error: 0.7744 - val_loss: 0.7059 - val_mean_absolute_error: 0.6554 - val_mean_squared_error: 0.7059
# Epoch 77/100
# 300/300 [==============================] - 0s 70us/sample - loss: 0.7947 - mean_absolute_error: 0.7196 - mean_squared_error: 0.7947 - val_loss: 0.7418 - val_mean_absolute_error: 0.6826 - val_mean_squared_error: 0.7418
# Epoch 78/100
# 300/300 [==============================] - 0s 73us/sample - loss: 0.7970 - mean_absolute_error: 0.7132 - mean_squared_error: 0.7970 - val_loss: 0.8508 - val_mean_absolute_error: 0.7527 - val_mean_squared_error: 0.8508
# Epoch 79/100
# 300/300 [==============================] - 0s 87us/sample - loss: 0.8541 - mean_absolute_error: 0.7322 - mean_squared_error: 0.8541 - val_loss: 0.8889 - val_mean_absolute_error: 0.7567 - val_mean_squared_error: 0.8889
# Epoch 80/100
# 300/300 [==============================] - 0s 70us/sample - loss: 0.8698 - mean_absolute_error: 0.7466 - mean_squared_error: 0.8698 - val_loss: 0.7279 - val_mean_absolute_error: 0.6820 - val_mean_squared_error: 0.7279
# Epoch 81/100
# 300/300 [==============================] - 0s 87us/sample - loss: 0.7949 - mean_absolute_error: 0.7048 - mean_squared_error: 0.7949 - val_loss: 0.5856 - val_mean_absolute_error: 0.6136 - val_mean_squared_error: 0.5856
# Epoch 82/100
# 300/300 [==============================] - 0s 70us/sample - loss: 0.8066 - mean_absolute_error: 0.6998 - mean_squared_error: 0.8066 - val_loss: 0.7072 - val_mean_absolute_error: 0.6701 - val_mean_squared_error: 0.7072
# Epoch 83/100
# 300/300 [==============================] - 0s 80us/sample - loss: 0.7968 - mean_absolute_error: 0.7159 - mean_squared_error: 0.7968 - val_loss: 0.7311 - val_mean_absolute_error: 0.6894 - val_mean_squared_error: 0.7311
# Epoch 84/100
# 300/300 [==============================] - 0s 97us/sample - loss: 0.7070 - mean_absolute_error: 0.6818 - mean_squared_error: 0.7070 - val_loss: 0.7366 - val_mean_absolute_error: 0.6866 - val_mean_squared_error: 0.7366
# Epoch 85/100
# 300/300 [==============================] - 0s 80us/sample - loss: 0.8133 - mean_absolute_error: 0.7263 - mean_squared_error: 0.8133 - val_loss: 0.7402 - val_mean_absolute_error: 0.6876 - val_mean_squared_error: 0.7402
# Epoch 86/100
# 300/300 [==============================] - 0s 83us/sample - loss: 0.8849 - mean_absolute_error: 0.7514 - mean_squared_error: 0.8849 - val_loss: 0.6766 - val_mean_absolute_error: 0.6576 - val_mean_squared_error: 0.6766
# Epoch 87/100
# 300/300 [==============================] - 0s 80us/sample - loss: 0.8116 - mean_absolute_error: 0.7254 - mean_squared_error: 0.8116 - val_loss: 0.7820 - val_mean_absolute_error: 0.7019 - val_mean_squared_error: 0.7820
# Epoch 88/100
# 300/300 [==============================] - 0s 77us/sample - loss: 0.7381 - mean_absolute_error: 0.6827 - mean_squared_error: 0.7381 - val_loss: 0.7010 - val_mean_absolute_error: 0.6601 - val_mean_squared_error: 0.7010
# Epoch 89/100
# 300/300 [==============================] - 0s 77us/sample - loss: 0.7825 - mean_absolute_error: 0.7036 - mean_squared_error: 0.7825 - val_loss: 0.5997 - val_mean_absolute_error: 0.6168 - val_mean_squared_error: 0.5997
# Epoch 90/100
# 300/300 [==============================] - 0s 77us/sample - loss: 0.7830 - mean_absolute_error: 0.7102 - mean_squared_error: 0.7830 - val_loss: 0.6817 - val_mean_absolute_error: 0.6450 - val_mean_squared_error: 0.6817
# Epoch 91/100
# 300/300 [==============================] - 0s 80us/sample - loss: 0.7786 - mean_absolute_error: 0.6914 - mean_squared_error: 0.7786 - val_loss: 0.8086 - val_mean_absolute_error: 0.7179 - val_mean_squared_error: 0.8086
# Epoch 92/100
# 300/300 [==============================] - 0s 80us/sample - loss: 0.7928 - mean_absolute_error: 0.7083 - mean_squared_error: 0.7928 - val_loss: 0.6653 - val_mean_absolute_error: 0.6542 - val_mean_squared_error: 0.6653
# Epoch 93/100
# 300/300 [==============================] - 0s 77us/sample - loss: 0.7281 - mean_absolute_error: 0.6711 - mean_squared_error: 0.7281 - val_loss: 0.6160 - val_mean_absolute_error: 0.6234 - val_mean_squared_error: 0.6160
# Epoch 94/100
# 300/300 [==============================] - 0s 80us/sample - loss: 0.7347 - mean_absolute_error: 0.6937 - mean_squared_error: 0.7347 - val_loss: 0.7205 - val_mean_absolute_error: 0.6819 - val_mean_squared_error: 0.7205
# Epoch 95/100
# 300/300 [==============================] - 0s 70us/sample - loss: 0.7149 - mean_absolute_error: 0.6834 - mean_squared_error: 0.7149 - val_loss: 0.6797 - val_mean_absolute_error: 0.6460 - val_mean_squared_error: 0.6797
# Epoch 96/100
# 300/300 [==============================] - 0s 77us/sample - loss: 0.6902 - mean_absolute_error: 0.6743 - mean_squared_error: 0.6902 - val_loss: 0.6450 - val_mean_absolute_error: 0.6406 - val_mean_squared_error: 0.6450
# Epoch 97/100
# 300/300 [==============================] - 0s 73us/sample - loss: 0.7527 - mean_absolute_error: 0.7063 - mean_squared_error: 0.7527 - val_loss: 0.5954 - val_mean_absolute_error: 0.6107 - val_mean_squared_error: 0.5954
# Epoch 98/100
# 300/300 [==============================] - 0s 90us/sample - loss: 0.6346 - mean_absolute_error: 0.6198 - mean_squared_error: 0.6346 - val_loss: 0.6284 - val_mean_absolute_error: 0.6315 - val_mean_squared_error: 0.6284
# Epoch 99/100
# 300/300 [==============================] - 0s 77us/sample - loss: 0.7217 - mean_absolute_error: 0.6736 - mean_squared_error: 0.7217 - val_loss: 0.6429 - val_mean_absolute_error: 0.6426 - val_mean_squared_error: 0.6429
# Epoch 100/100
# 300/300 [==============================] - 0s 83us/sample - loss: 0.6323 - mean_absolute_error: 0.6315 - mean_squared_error: 0.6323 - val_loss: 0.6807 - val_mean_absolute_error: 0.6532 - val_mean_squared_error: 0.6807

# %% [markdown]
# Evaluations:

# %%
val = model1.evaluate(x_v, y_v, verbose=2)

print("Testing: Loss: {:.5f}, Mean Absolute Error: {:.5f}, MSE: {:.5f} for median_house_value".format(val[0],val[1],val[2]))
# Out:
# 76/76 - 0s - loss: 0.6807 - mean_absolute_error: 0.6532 - mean_squared_error: 0.6807
# Testing: Loss: 0.68068, Mean Absolute Error: 0.65321, MSE: 0.68068 for median_house_value

# %% [markdown]
# Visualization:
#
# Visualizing the Loss and Accuracy vs epochs:

# %%
def plot_history(history):
    hist = pd.DataFrame(history.history)
    hist['epoch'] = history.epoch

    pyplot.figure(figsize=(15,5))

    pyplot.subplot(121)
    pyplot.xlabel('Epoch')
    pyplot.ylabel('Mean Abs Error')
    pyplot.plot(hist['epoch'], hist['mean_absolute_error'], label='Train Error')
    pyplot.plot(hist['epoch'], hist['val_mean_absolute_error'], label = 'Validation Error')
    pyplot.legend()

    pyplot.subplot(122)
    pyplot.xlabel('Epoch')
    pyplot.ylabel('Mean Square Error')
    pyplot.plot(hist['epoch'], hist['mean_squared_error'], label='Train Error')
    pyplot.plot(hist['epoch'], hist['val_mean_squared_error'], label = 'Validation Error')
    pyplot.legend()
    pyplot.show()


plot_history(history)

# %% [markdown]
# Very well!

# %% [markdown]
# Predictions:

# %%
test_predictions = model1.predict(x_v).flatten()

predicted_loss = np.abs(y_v.values[0:4]-test_predictions[0:4])/y_v.describe().transpose()['mean']

print("\nReal quality values:\n", y_v.values[0:4])
print("\nPredicted quality values:\n", test_predictions[0:4])
print("\nLoss:\n", predicted_loss)
# Out:
# Real quality values:
#  [5 7 6 5]
#
# Predicted quality values:
#  [5.9150977 6.6866984 6.1110444 5.66107  ]
#
# Loss:
#  [0.15770391 0.05399301 0.0191369  0.11392587]

# %%
def plot_results(X, Y, Y_predict, plot_name):
    pyplot.figure()
    pyplot.scatter(Y, Y_predict)
    pyplot.grid()
    pyplot.xlabel("Real Qualities")
    pyplot.ylabel("Predictions Qualities")
    pyplot.figure()
    pyplot.scatter(X['alcohol'], Y, label="values")
    pyplot.plot(X['alcohol'], Y_predict, color="red", label="model")
    pyplot.grid()
    pyplot.xlabel("alcohol")
    pyplot.ylabel("quality")
    pyplot.legend()

test_predictions = model1.predict(x_v).flatten()
plot_results(x_v, y_v, test_predictions, "results_nn.png")

# %% [markdown]
# Hmmm, not a good linear line, but almost makes it.

# %%
error = test_predictions - y_v
pyplot.hist(error, bins = 25)
pyplot.xlabel("Prediction Error")
_ = pyplot.ylabel("Count")
pyplot.show()

# %% [markdown]
# Let's do it agian using another model, and this time we add more layers.

# %%
def build_model2():
    model = keras.Sequential()
    model.add(keras.layers.Dense(64, input_shape=[len(x_t.columns),], activation="relu"))
    for i in range(5):
        model.add(keras.layers.Dropout(.2))
        model.add(keras.layers.Dense(128, activation="relu"))
    model.add(keras.layers.Dense(64, activation="relu"))
    model.add(keras.layers.Dense(1))
    
    optimizer = tf.keras.optimizers.RMSprop(0.001, clipnorm=1)

    model.compile(loss='mean_squared_error',
                optimizer=optimizer,
                metrics=['mean_absolute_error',
                         'mean_squared_error',
                         'mean_squared_logarithmic_error'])
    return model

model2 = build_model2()
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 64)                768
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 83,457
# Trainable params: 83,457
# Non-trainable params: 0
# _________________________________________________________________

# %%
history2 = model2.fit(
    x_t, y_t,
    validation_data=(x_v, y_v),
    verbose=1, epochs=100)
# Out:
# Train on 300 samples, validate on 76 samples
# Epoch 1/100
# 300/300 [==============================] - 0s 2ms/sample - loss: 33.4770 - mean_absolute_error: 4.1903 - mean_squared_error: 33.4770 - mean_squared_logarithmic_error: 0.9272 - val_loss: 11.0276 - val_mean_absolute_error: 3.1477 - val_mean_squared_error: 11.0276 - val_mean_squared_logarithmic_error: 0.4518
# Epoch 2/100
# 300/300 [==============================] - 0s 160us/sample - loss: 7.2086 - mean_absolute_error: 2.1616 - mean_squared_error: 7.2086 - mean_squared_logarithmic_error: 0.2127 - val_loss: 8.9315 - val_mean_absolute_error: 2.7765 - val_mean_squared_error: 8.9315 - val_mean_squared_logarithmic_error: 0.3380
# Epoch 3/100
# 300/300 [==============================] - 0s 163us/sample - loss: 7.5900 - mean_absolute_error: 2.1631 - mean_squared_error: 7.5900 - mean_squared_logarithmic_error: 0.1958 - val_loss: 10.8803 - val_mean_absolute_error: 3.1222 - val_mean_squared_error: 10.8803 - val_mean_squared_logarithmic_error: 0.4414
# Epoch 4/100
# 300/300 [==============================] - 0s 147us/sample - loss: 7.8361 - mean_absolute_error: 2.2104 - mean_squared_error: 7.8361 - mean_squared_logarithmic_error: 0.1793 - val_loss: 11.9442 - val_mean_absolute_error: 3.2946 - val_mean_squared_error: 11.9442 - val_mean_squared_logarithmic_error: 0.5052
# Epoch 5/100
# 300/300 [==============================] - 0s 140us/sample - loss: 6.6746 - mean_absolute_error: 2.0736 - mean_squared_error: 6.6746 - mean_squared_logarithmic_error: 0.1699 - val_loss: 8.7745 - val_mean_absolute_error: 2.7412 - val_mean_squared_error: 8.7745 - val_mean_squared_logarithmic_error: 0.3319
# Epoch 6/100
# 300/300 [==============================] - 0s 140us/sample - loss: 5.8240 - mean_absolute_error: 1.9025 - mean_squared_error: 5.8240 - mean_squared_logarithmic_error: 0.1315 - val_loss: 18.1688 - val_mean_absolute_error: 4.1748 - val_mean_squared_error: 18.1688 - val_mean_squared_logarithmic_error: 0.9436
# Epoch 7/100
# 300/300 [==============================] - 0s 133us/sample - loss: 5.4624 - mean_absolute_error: 1.9089 - mean_squared_error: 5.4624 - mean_squared_logarithmic_error: 0.1443 - val_loss: 8.5193 - val_mean_absolute_error: 2.7027 - val_mean_squared_error: 8.5193 - val_mean_squared_logarithmic_error: 0.3156
# Epoch 8/100
# 300/300 [==============================] - 0s 120us/sample - loss: 6.3682 - mean_absolute_error: 2.0205 - mean_squared_error: 6.3682 - mean_squared_logarithmic_error: 0.1575 - val_loss: 6.8188 - val_mean_absolute_error: 2.3447 - val_mean_squared_error: 6.8188 - val_mean_squared_logarithmic_error: 0.2370
# Epoch 9/100
# 300/300 [==============================] - 0s 153us/sample - loss: 5.6483 - mean_absolute_error: 1.8559 - mean_squared_error: 5.6483 - mean_squared_logarithmic_error: 0.1330 - val_loss: 3.7979 - val_mean_absolute_error: 1.6067 - val_mean_squared_error: 3.7979 - val_mean_squared_logarithmic_error: 0.1150
# Epoch 10/100
# 300/300 [==============================] - 0s 150us/sample - loss: 5.5423 - mean_absolute_error: 1.8745 - mean_squared_error: 5.5423 - mean_squared_logarithmic_error: 0.1275 - val_loss: 11.1692 - val_mean_absolute_error: 3.2003 - val_mean_squared_error: 11.1692 - val_mean_squared_logarithmic_error: 0.4484
# Epoch 11/100
# 300/300 [==============================] - 0s 143us/sample - loss: 5.2761 - mean_absolute_error: 1.8642 - mean_squared_error: 5.2761 - mean_squared_logarithmic_error: 0.1285 - val_loss: 9.3416 - val_mean_absolute_error: 2.8886 - val_mean_squared_error: 9.3416 - val_mean_squared_logarithmic_error: 0.3510
# Epoch 12/100
# 300/300 [==============================] - 0s 137us/sample - loss: 4.7451 - mean_absolute_error: 1.7672 - mean_squared_error: 4.7451 - mean_squared_logarithmic_error: 0.1169 - val_loss: 8.2864 - val_mean_absolute_error: 2.6974 - val_mean_squared_error: 8.2864 - val_mean_squared_logarithmic_error: 0.2980
# Epoch 13/100
# 300/300 [==============================] - 0s 147us/sample - loss: 5.0722 - mean_absolute_error: 1.8132 - mean_squared_error: 5.0722 - mean_squared_logarithmic_error: 0.1246 - val_loss: 7.3679 - val_mean_absolute_error: 2.5134 - val_mean_squared_error: 7.3679 - val_mean_squared_logarithmic_error: 0.2550
# Epoch 14/100
# 300/300 [==============================] - 0s 137us/sample - loss: 4.6052 - mean_absolute_error: 1.7269 - mean_squared_error: 4.6052 - mean_squared_logarithmic_error: 0.1169 - val_loss: 10.8881 - val_mean_absolute_error: 3.1758 - val_mean_squared_error: 10.8881 - val_mean_squared_logarithmic_error: 0.4261
# Epoch 15/100
# 300/300 [==============================] - ETA: 0s - loss: 3.2999 - mean_absolute_error: 1.4890 - mean_squared_error: 3.2999 - mean_squared_logarithmic_error: 0.099 - 0s 127us/sample - loss: 4.9666 - mean_absolute_error: 1.8027 - mean_squared_error: 4.9666 - mean_squared_logarithmic_error: 0.1229 - val_loss: 4.5016 - val_mean_absolute_error: 1.8201 - val_mean_squared_error: 4.5016 - val_mean_squared_logarithmic_error: 0.1382
# Epoch 16/100
# 300/300 [==============================] - 0s 150us/sample - loss: 5.3167 - mean_absolute_error: 1.8237 - mean_squared_error: 5.3167 - mean_squared_logarithmic_error: 0.1092 - val_loss: 9.4339 - val_mean_absolute_error: 2.9220 - val_mean_squared_error: 9.4339 - val_mean_squared_logarithmic_error: 0.3509
# Epoch 17/100
# 300/300 [==============================] - 0s 130us/sample - loss: 4.9016 - mean_absolute_error: 1.8116 - mean_squared_error: 4.9016 - mean_squared_logarithmic_error: 0.1187 - val_loss: 10.7751 - val_mean_absolute_error: 3.1589 - val_mean_squared_error: 10.7751 - val_mean_squared_logarithmic_error: 0.4190
# Epoch 18/100
# 300/300 [==============================] - 0s 133us/sample - loss: 4.3431 - mean_absolute_error: 1.6652 - mean_squared_error: 4.3431 - mean_squared_logarithmic_error: 0.0948 - val_loss: 12.0387 - val_mean_absolute_error: 3.3596 - val_mean_squared_error: 12.0387 - val_mean_squared_logarithmic_error: 0.4900
# Epoch 19/100
# 300/300 [==============================] - 0s 140us/sample - loss: 4.2926 - mean_absolute_error: 1.6478 - mean_squared_error: 4.2926 - mean_squared_logarithmic_error: 0.0951 - val_loss: 7.7686 - val_mean_absolute_error: 2.6352 - val_mean_squared_error: 7.7686 - val_mean_squared_logarithmic_error: 0.2667
# Epoch 20/100
# 300/300 [==============================] - 0s 127us/sample - loss: 4.1493 - mean_absolute_error: 1.6455 - mean_squared_error: 4.1493 - mean_squared_logarithmic_error: 0.0937 - val_loss: 12.2245 - val_mean_absolute_error: 3.3980 - val_mean_squared_error: 12.2245 - val_mean_squared_logarithmic_error: 0.4982
# Epoch 21/100
# 300/300 [==============================] - 0s 123us/sample - loss: 4.1636 - mean_absolute_error: 1.5916 - mean_squared_error: 4.1636 - mean_squared_logarithmic_error: 0.0932 - val_loss: 12.5783 - val_mean_absolute_error: 3.4505 - val_mean_squared_error: 12.5783 - val_mean_squared_logarithmic_error: 0.5192
# Epoch 22/100
# 300/300 [==============================] - 0s 137us/sample - loss: 4.3546 - mean_absolute_error: 1.6754 - mean_squared_error: 4.3546 - mean_squared_logarithmic_error: 0.0987 - val_loss: 8.3591 - val_mean_absolute_error: 2.7692 - val_mean_squared_error: 8.3591 - val_mean_squared_logarithmic_error: 0.2908
# Epoch 23/100
# 300/300 [==============================] - 0s 130us/sample - loss: 3.4297 - mean_absolute_error: 1.4873 - mean_squared_error: 3.4297 - mean_squared_logarithmic_error: 0.0808 - val_loss: 10.3869 - val_mean_absolute_error: 3.1258 - val_mean_squared_error: 10.3869 - val_mean_squared_logarithmic_error: 0.3906
# Epoch 24/100
# 300/300 [==============================] - 0s 140us/sample - loss: 3.9361 - mean_absolute_error: 1.5672 - mean_squared_error: 3.9361 - mean_squared_logarithmic_error: 0.0879 - val_loss: 10.5582 - val_mean_absolute_error: 3.1574 - val_mean_squared_error: 10.5582 - val_mean_squared_logarithmic_error: 0.3989
# Epoch 25/100
# 300/300 [==============================] - 0s 137us/sample - loss: 3.6242 - mean_absolute_error: 1.5525 - mean_squared_error: 3.6242 - mean_squared_logarithmic_error: 0.0832 - val_loss: 5.2142 - val_mean_absolute_error: 2.1357 - val_mean_squared_error: 5.2142 - val_mean_squared_logarithmic_error: 0.1559
# Epoch 26/100
# 300/300 [==============================] - 0s 150us/sample - loss: 3.4140 - mean_absolute_error: 1.4755 - mean_squared_error: 3.4140 - mean_squared_logarithmic_error: 0.0732 - val_loss: 11.6766 - val_mean_absolute_error: 3.3345 - val_mean_squared_error: 11.6766 - val_mean_squared_logarithmic_error: 0.4607
# Epoch 27/100
# 300/300 [==============================] - 0s 137us/sample - loss: 3.3779 - mean_absolute_error: 1.4720 - mean_squared_error: 3.3779 - mean_squared_logarithmic_error: 0.0779 - val_loss: 4.6938 - val_mean_absolute_error: 2.0317 - val_mean_squared_error: 4.6938 - val_mean_squared_logarithmic_error: 0.1361
# Epoch 28/100
# 300/300 [==============================] - 0s 143us/sample - loss: 3.5529 - mean_absolute_error: 1.4752 - mean_squared_error: 3.5529 - mean_squared_logarithmic_error: 0.0731 - val_loss: 8.5591 - val_mean_absolute_error: 2.8293 - val_mean_squared_error: 8.5591 - val_mean_squared_logarithmic_error: 0.2971
# Epoch 29/100
# 300/300 [==============================] - 0s 140us/sample - loss: 2.9489 - mean_absolute_error: 1.3293 - mean_squared_error: 2.9489 - mean_squared_logarithmic_error: 0.0645 - val_loss: 10.8781 - val_mean_absolute_error: 3.2199 - val_mean_squared_error: 10.8781 - val_mean_squared_logarithmic_error: 0.4164
# Epoch 30/100
# 300/300 [==============================] - 0s 147us/sample - loss: 2.9464 - mean_absolute_error: 1.3775 - mean_squared_error: 2.9464 - mean_squared_logarithmic_error: 0.0645 - val_loss: 10.0285 - val_mean_absolute_error: 3.0873 - val_mean_squared_error: 10.0285 - val_mean_squared_logarithmic_error: 0.3712
# Epoch 31/100
# 300/300 [==============================] - 0s 150us/sample - loss: 3.2232 - mean_absolute_error: 1.3653 - mean_squared_error: 3.2232 - mean_squared_logarithmic_error: 0.0666 - val_loss: 7.8940 - val_mean_absolute_error: 2.7204 - val_mean_squared_error: 7.8940 - val_mean_squared_logarithmic_error: 0.2680
# Epoch 32/100
# 300/300 [==============================] - 0s 157us/sample - loss: 3.1574 - mean_absolute_error: 1.4048 - mean_squared_error: 3.1574 - mean_squared_logarithmic_error: 0.0678 - val_loss: 4.6081 - val_mean_absolute_error: 2.0281 - val_mean_squared_error: 4.6081 - val_mean_squared_logarithmic_error: 0.1336
# Epoch 33/100
# 300/300 [==============================] - 0s 157us/sample - loss: 2.8532 - mean_absolute_error: 1.3037 - mean_squared_error: 2.8532 - mean_squared_logarithmic_error: 0.0586 - val_loss: 3.1855 - val_mean_absolute_error: 1.6346 - val_mean_squared_error: 3.1855 - val_mean_squared_logarithmic_error: 0.0866
# Epoch 34/100
# 300/300 [==============================] - 0s 157us/sample - loss: 4.9647 - mean_absolute_error: 1.6869 - mean_squared_error: 4.9647 - mean_squared_logarithmic_error: 0.0873 - val_loss: 10.7515 - val_mean_absolute_error: 3.2021 - val_mean_squared_error: 10.7515 - val_mean_squared_logarithmic_error: 0.4126
# Epoch 35/100
# 300/300 [==============================] - 0s 153us/sample - loss: 3.0237 - mean_absolute_error: 1.3524 - mean_squared_error: 3.0237 - mean_squared_logarithmic_error: 0.0637 - val_loss: 8.4096 - val_mean_absolute_error: 2.8127 - val_mean_squared_error: 8.4096 - val_mean_squared_logarithmic_error: 0.2917
# Epoch 36/100
# 300/300 [==============================] - 0s 140us/sample - loss: 2.8533 - mean_absolute_error: 1.3264 - mean_squared_error: 2.8533 - mean_squared_logarithmic_error: 0.0627 - val_loss: 5.3821 - val_mean_absolute_error: 2.2104 - val_mean_squared_error: 5.3821 - val_mean_squared_logarithmic_error: 0.1628
# Epoch 37/100
# 300/300 [==============================] - 0s 160us/sample - loss: 3.0700 - mean_absolute_error: 1.3369 - mean_squared_error: 3.0700 - mean_squared_logarithmic_error: 0.0614 - val_loss: 5.5721 - val_mean_absolute_error: 2.2518 - val_mean_squared_error: 5.5721 - val_mean_squared_logarithmic_error: 0.1699
# Epoch 38/100
# 300/300 [==============================] - 0s 153us/sample - loss: 2.6404 - mean_absolute_error: 1.2568 - mean_squared_error: 2.6404 - mean_squared_logarithmic_error: 0.0537 - val_loss: 12.0989 - val_mean_absolute_error: 3.4024 - val_mean_squared_error: 12.0989 - val_mean_squared_logarithmic_error: 0.4891
# Epoch 39/100
# 300/300 [==============================] - 0s 160us/sample - loss: 2.8980 - mean_absolute_error: 1.3679 - mean_squared_error: 2.8980 - mean_squared_logarithmic_error: 0.0636 - val_loss: 7.9812 - val_mean_absolute_error: 2.7338 - val_mean_squared_error: 7.9812 - val_mean_squared_logarithmic_error: 0.2707
# Epoch 40/100
# 300/300 [==============================] - 0s 163us/sample - loss: 2.5935 - mean_absolute_error: 1.2692 - mean_squared_error: 2.5935 - mean_squared_logarithmic_error: 0.0550 - val_loss: 5.8262 - val_mean_absolute_error: 2.3017 - val_mean_squared_error: 5.8262 - val_mean_squared_logarithmic_error: 0.1835
# Epoch 41/100
# 300/300 [==============================] - 0s 157us/sample - loss: 2.6761 - mean_absolute_error: 1.3027 - mean_squared_error: 2.6761 - mean_squared_logarithmic_error: 0.0590 - val_loss: 11.6910 - val_mean_absolute_error: 3.3445 - val_mean_squared_error: 11.6910 - val_mean_squared_logarithmic_error: 0.4662
# Epoch 42/100
# 300/300 [==============================] - 0s 140us/sample - loss: 2.1419 - mean_absolute_error: 1.1518 - mean_squared_error: 2.1419 - mean_squared_logarithmic_error: 0.0445 - val_loss: 8.4760 - val_mean_absolute_error: 2.8224 - val_mean_squared_error: 8.4760 - val_mean_squared_logarithmic_error: 0.2993
# Epoch 43/100
# 300/300 [==============================] - 0s 127us/sample - loss: 2.4789 - mean_absolute_error: 1.2452 - mean_squared_error: 2.4789 - mean_squared_logarithmic_error: 0.0552 - val_loss: 12.3774 - val_mean_absolute_error: 3.4457 - val_mean_squared_error: 12.3774 - val_mean_squared_logarithmic_error: 0.5076
# Epoch 44/100
# 300/300 [==============================] - 0s 137us/sample - loss: 2.9742 - mean_absolute_error: 1.3141 - mean_squared_error: 2.9742 - mean_squared_logarithmic_error: 0.0611 - val_loss: 5.2346 - val_mean_absolute_error: 2.1781 - val_mean_squared_error: 5.2346 - val_mean_squared_logarithmic_error: 0.1566
# Epoch 45/100
# 300/300 [==============================] - 0s 127us/sample - loss: 2.4026 - mean_absolute_error: 1.2290 - mean_squared_error: 2.4026 - mean_squared_logarithmic_error: 0.0514 - val_loss: 6.0978 - val_mean_absolute_error: 2.3672 - val_mean_squared_error: 6.0978 - val_mean_squared_logarithmic_error: 0.1913
# Epoch 46/100
# 300/300 [==============================] - 0s 133us/sample - loss: 2.5780 - mean_absolute_error: 1.2585 - mean_squared_error: 2.5780 - mean_squared_logarithmic_error: 0.0522 - val_loss: 4.2528 - val_mean_absolute_error: 1.9319 - val_mean_squared_error: 4.2528 - val_mean_squared_logarithmic_error: 0.1240
# Epoch 47/100
# 300/300 [==============================] - 0s 150us/sample - loss: 2.3202 - mean_absolute_error: 1.1988 - mean_squared_error: 2.3202 - mean_squared_logarithmic_error: 0.0492 - val_loss: 7.6232 - val_mean_absolute_error: 2.6698 - val_mean_squared_error: 7.6232 - val_mean_squared_logarithmic_error: 0.2580
# Epoch 48/100
# 300/300 [==============================] - 0s 133us/sample - loss: 2.4776 - mean_absolute_error: 1.2440 - mean_squared_error: 2.4776 - mean_squared_logarithmic_error: 0.0532 - val_loss: 8.7530 - val_mean_absolute_error: 2.8743 - val_mean_squared_error: 8.7530 - val_mean_squared_logarithmic_error: 0.3080
# Epoch 49/100
# 300/300 [==============================] - 0s 130us/sample - loss: 2.3517 - mean_absolute_error: 1.1792 - mean_squared_error: 2.3517 - mean_squared_logarithmic_error: 0.0496 - val_loss: 2.7808 - val_mean_absolute_error: 1.5285 - val_mean_squared_error: 2.7808 - val_mean_squared_logarithmic_error: 0.0725
# Epoch 50/100
# 300/300 [==============================] - 0s 137us/sample - loss: 2.8035 - mean_absolute_error: 1.2694 - mean_squared_error: 2.8035 - mean_squared_logarithmic_error: 0.0543 - val_loss: 9.6106 - val_mean_absolute_error: 3.0186 - val_mean_squared_error: 9.6106 - val_mean_squared_logarithmic_error: 0.3531
# Epoch 51/100
# 300/300 [==============================] - 0s 143us/sample - loss: 2.0790 - mean_absolute_error: 1.1535 - mean_squared_error: 2.0790 - mean_squared_logarithmic_error: 0.0468 - val_loss: 4.2157 - val_mean_absolute_error: 1.9311 - val_mean_squared_error: 4.2157 - val_mean_squared_logarithmic_error: 0.1214
# Epoch 52/100
# 300/300 [==============================] - 0s 137us/sample - loss: 2.3374 - mean_absolute_error: 1.2078 - mean_squared_error: 2.3374 - mean_squared_logarithmic_error: 0.0488 - val_loss: 6.0571 - val_mean_absolute_error: 2.3607 - val_mean_squared_error: 6.0571 - val_mean_squared_logarithmic_error: 0.1908
# Epoch 53/100
# 300/300 [==============================] - 0s 133us/sample - loss: 2.1878 - mean_absolute_error: 1.1546 - mean_squared_error: 2.1878 - mean_squared_logarithmic_error: 0.0470 - val_loss: 4.2903 - val_mean_absolute_error: 1.9472 - val_mean_squared_error: 4.2903 - val_mean_squared_logarithmic_error: 0.1252
# Epoch 54/100
# 300/300 [==============================] - 0s 127us/sample - loss: 2.2573 - mean_absolute_error: 1.1908 - mean_squared_error: 2.2573 - mean_squared_logarithmic_error: 0.0484 - val_loss: 4.2601 - val_mean_absolute_error: 1.9458 - val_mean_squared_error: 4.2601 - val_mean_squared_logarithmic_error: 0.1223
# Epoch 55/100
# 300/300 [==============================] - 0s 123us/sample - loss: 2.1670 - mean_absolute_error: 1.1559 - mean_squared_error: 2.1670 - mean_squared_logarithmic_error: 0.0449 - val_loss: 8.0651 - val_mean_absolute_error: 2.7522 - val_mean_squared_error: 8.0651 - val_mean_squared_logarithmic_error: 0.2788
# Epoch 56/100
# 300/300 [==============================] - 0s 150us/sample - loss: 2.2047 - mean_absolute_error: 1.1498 - mean_squared_error: 2.2047 - mean_squared_logarithmic_error: 0.0460 - val_loss: 6.0700 - val_mean_absolute_error: 2.3650 - val_mean_squared_error: 6.0700 - val_mean_squared_logarithmic_error: 0.1913
# Epoch 57/100
# 300/300 [==============================] - 0s 143us/sample - loss: 2.0560 - mean_absolute_error: 1.1184 - mean_squared_error: 2.0560 - mean_squared_logarithmic_error: 0.0431 - val_loss: 8.4213 - val_mean_absolute_error: 2.8185 - val_mean_squared_error: 8.4213 - val_mean_squared_logarithmic_error: 0.2938
# Epoch 58/100
# 300/300 [==============================] - 0s 143us/sample - loss: 2.1150 - mean_absolute_error: 1.1651 - mean_squared_error: 2.1150 - mean_squared_logarithmic_error: 0.0447 - val_loss: 8.6362 - val_mean_absolute_error: 2.8569 - val_mean_squared_error: 8.6362 - val_mean_squared_logarithmic_error: 0.3041
# Epoch 59/100
# 300/300 [==============================] - 0s 123us/sample - loss: 2.8269 - mean_absolute_error: 1.3368 - mean_squared_error: 2.8269 - mean_squared_logarithmic_error: 0.0599 - val_loss: 8.2195 - val_mean_absolute_error: 2.7830 - val_mean_squared_error: 8.2195 - val_mean_squared_logarithmic_error: 0.2845
# Epoch 60/100
# 300/300 [==============================] - 0s 150us/sample - loss: 2.0816 - mean_absolute_error: 1.1339 - mean_squared_error: 2.0816 - mean_squared_logarithmic_error: 0.0465 - val_loss: 9.1837 - val_mean_absolute_error: 2.9478 - val_mean_squared_error: 9.1837 - val_mean_squared_logarithmic_error: 0.3335
# Epoch 61/100
# 300/300 [==============================] - 0s 147us/sample - loss: 2.1740 - mean_absolute_error: 1.1957 - mean_squared_error: 2.1740 - mean_squared_logarithmic_error: 0.0488 - val_loss: 8.5924 - val_mean_absolute_error: 2.8459 - val_mean_squared_error: 8.5924 - val_mean_squared_logarithmic_error: 0.3035
# Epoch 62/100
# 300/300 [==============================] - 0s 137us/sample - loss: 2.1094 - mean_absolute_error: 1.1538 - mean_squared_error: 2.1094 - mean_squared_logarithmic_error: 0.0458 - val_loss: 9.4295 - val_mean_absolute_error: 2.9901 - val_mean_squared_error: 9.4295 - val_mean_squared_logarithmic_error: 0.3443
# Epoch 63/100
# 300/300 [==============================] - 0s 143us/sample - loss: 1.8105 - mean_absolute_error: 1.0679 - mean_squared_error: 1.8105 - mean_squared_logarithmic_error: 0.0384 - val_loss: 4.9426 - val_mean_absolute_error: 2.1033 - val_mean_squared_error: 4.9426 - val_mean_squared_logarithmic_error: 0.1498
# Epoch 64/100
# 300/300 [==============================] - 0s 157us/sample - loss: 2.3099 - mean_absolute_error: 1.2081 - mean_squared_error: 2.3099 - mean_squared_logarithmic_error: 0.0485 - val_loss: 6.3446 - val_mean_absolute_error: 2.4200 - val_mean_squared_error: 6.3446 - val_mean_squared_logarithmic_error: 0.2028
# Epoch 65/100
# 300/300 [==============================] - 0s 157us/sample - loss: 2.2660 - mean_absolute_error: 1.1512 - mean_squared_error: 2.2660 - mean_squared_logarithmic_error: 0.0468 - val_loss: 7.4111 - val_mean_absolute_error: 2.6315 - val_mean_squared_error: 7.4111 - val_mean_squared_logarithmic_error: 0.2477
# Epoch 66/100
# 300/300 [==============================] - 0s 160us/sample - loss: 1.7436 - mean_absolute_error: 1.0512 - mean_squared_error: 1.7436 - mean_squared_logarithmic_error: 0.0367 - val_loss: 4.8515 - val_mean_absolute_error: 2.0919 - val_mean_squared_error: 4.8515 - val_mean_squared_logarithmic_error: 0.1430
# Epoch 67/100
# 300/300 [==============================] - 0s 153us/sample - loss: 2.1653 - mean_absolute_error: 1.1770 - mean_squared_error: 2.1653 - mean_squared_logarithmic_error: 0.0458 - val_loss: 5.1858 - val_mean_absolute_error: 2.1673 - val_mean_squared_error: 5.1858 - val_mean_squared_logarithmic_error: 0.1572
# Epoch 68/100
# 300/300 [==============================] - 0s 147us/sample - loss: 1.9099 - mean_absolute_error: 1.0879 - mean_squared_error: 1.9099 - mean_squared_logarithmic_error: 0.0407 - val_loss: 5.1215 - val_mean_absolute_error: 2.1565 - val_mean_squared_error: 5.1215 - val_mean_squared_logarithmic_error: 0.1540
# Epoch 69/100
# 300/300 [==============================] - 0s 150us/sample - loss: 1.9683 - mean_absolute_error: 1.1239 - mean_squared_error: 1.9683 - mean_squared_logarithmic_error: 0.0440 - val_loss: 6.0719 - val_mean_absolute_error: 2.3659 - val_mean_squared_error: 6.0719 - val_mean_squared_logarithmic_error: 0.1912
# Epoch 70/100
# 300/300 [==============================] - 0s 137us/sample - loss: 1.8642 - mean_absolute_error: 1.0657 - mean_squared_error: 1.8642 - mean_squared_logarithmic_error: 0.0409 - val_loss: 4.8075 - val_mean_absolute_error: 2.0831 - val_mean_squared_error: 4.8075 - val_mean_squared_logarithmic_error: 0.1422
# Epoch 71/100
# 300/300 [==============================] - 0s 157us/sample - loss: 2.0265 - mean_absolute_error: 1.1345 - mean_squared_error: 2.0265 - mean_squared_logarithmic_error: 0.0447 - val_loss: 5.0993 - val_mean_absolute_error: 2.1526 - val_mean_squared_error: 5.0993 - val_mean_squared_logarithmic_error: 0.1528
# Epoch 72/100
# 300/300 [==============================] - 0s 137us/sample - loss: 2.0839 - mean_absolute_error: 1.1022 - mean_squared_error: 2.0839 - mean_squared_logarithmic_error: 0.0421 - val_loss: 6.4033 - val_mean_absolute_error: 2.4375 - val_mean_squared_error: 6.4033 - val_mean_squared_logarithmic_error: 0.2037
# Epoch 73/100
# 300/300 [==============================] - 0s 127us/sample - loss: 1.8504 - mean_absolute_error: 1.1186 - mean_squared_error: 1.8504 - mean_squared_logarithmic_error: 0.0420 - val_loss: 6.5615 - val_mean_absolute_error: 2.4687 - val_mean_squared_error: 6.5615 - val_mean_squared_logarithmic_error: 0.2110
# Epoch 74/100
# 300/300 [==============================] - 0s 147us/sample - loss: 1.9283 - mean_absolute_error: 1.1071 - mean_squared_error: 1.9283 - mean_squared_logarithmic_error: 0.0409 - val_loss: 7.8353 - val_mean_absolute_error: 2.7069 - val_mean_squared_error: 7.8353 - val_mean_squared_logarithmic_error: 0.2709
# Epoch 75/100
# 300/300 [==============================] - 0s 170us/sample - loss: 1.4534 - mean_absolute_error: 0.9712 - mean_squared_error: 1.4534 - mean_squared_logarithmic_error: 0.0327 - val_loss: 7.6910 - val_mean_absolute_error: 2.6842 - val_mean_squared_error: 7.6910 - val_mean_squared_logarithmic_error: 0.2619
# Epoch 76/100
# 300/300 [==============================] - 0s 147us/sample - loss: 1.7043 - mean_absolute_error: 1.0384 - mean_squared_error: 1.7043 - mean_squared_logarithmic_error: 0.0379 - val_loss: 8.5941 - val_mean_absolute_error: 2.8497 - val_mean_squared_error: 8.5941 - val_mean_squared_logarithmic_error: 0.3022
# Epoch 77/100
# 300/300 [==============================] - 0s 153us/sample - loss: 2.0999 - mean_absolute_error: 1.1096 - mean_squared_error: 2.0999 - mean_squared_logarithmic_error: 0.0435 - val_loss: 8.0712 - val_mean_absolute_error: 2.7568 - val_mean_squared_error: 8.0712 - val_mean_squared_logarithmic_error: 0.2771
# Epoch 78/100
# 300/300 [==============================] - 0s 153us/sample - loss: 1.6085 - mean_absolute_error: 1.0004 - mean_squared_error: 1.6085 - mean_squared_logarithmic_error: 0.0355 - val_loss: 7.7525 - val_mean_absolute_error: 2.6953 - val_mean_squared_error: 7.7525 - val_mean_squared_logarithmic_error: 0.2650
# Epoch 79/100
# 300/300 [==============================] - 0s 150us/sample - loss: 1.9194 - mean_absolute_error: 1.0981 - mean_squared_error: 1.9194 - mean_squared_logarithmic_error: 0.0407 - val_loss: 7.8213 - val_mean_absolute_error: 2.7081 - val_mean_squared_error: 7.8213 - val_mean_squared_logarithmic_error: 0.2683
# Epoch 80/100
# 300/300 [==============================] - 0s 150us/sample - loss: 1.8806 - mean_absolute_error: 1.0810 - mean_squared_error: 1.8806 - mean_squared_logarithmic_error: 0.0398 - val_loss: 8.7205 - val_mean_absolute_error: 2.8717 - val_mean_squared_error: 8.7205 - val_mean_squared_logarithmic_error: 0.3090
# Epoch 81/100
# 300/300 [==============================] - 0s 163us/sample - loss: 1.4455 - mean_absolute_error: 1.0036 - mean_squared_error: 1.4455 - mean_squared_logarithmic_error: 0.0322 - val_loss: 8.1101 - val_mean_absolute_error: 2.7654 - val_mean_squared_error: 8.1101 - val_mean_squared_logarithmic_error: 0.2778
# Epoch 82/100
# 300/300 [==============================] - 0s 153us/sample - loss: 1.9109 - mean_absolute_error: 1.0753 - mean_squared_error: 1.9109 - mean_squared_logarithmic_error: 0.0399 - val_loss: 8.6979 - val_mean_absolute_error: 2.8689 - val_mean_squared_error: 8.6979 - val_mean_squared_logarithmic_error: 0.3065
# Epoch 83/100
# 300/300 [==============================] - 0s 150us/sample - loss: 1.9563 - mean_absolute_error: 1.0672 - mean_squared_error: 1.9563 - mean_squared_logarithmic_error: 0.0415 - val_loss: 8.7175 - val_mean_absolute_error: 2.8701 - val_mean_squared_error: 8.7175 - val_mean_squared_logarithmic_error: 0.3095
# Epoch 84/100
# 300/300 [==============================] - 0s 130us/sample - loss: 1.8436 - mean_absolute_error: 1.0734 - mean_squared_error: 1.8436 - mean_squared_logarithmic_error: 0.0391 - val_loss: 8.8464 - val_mean_absolute_error: 2.8947 - val_mean_squared_error: 8.8464 - val_mean_squared_logarithmic_error: 0.3141
# Epoch 85/100
# 300/300 [==============================] - 0s 137us/sample - loss: 1.7568 - mean_absolute_error: 1.0798 - mean_squared_error: 1.7568 - mean_squared_logarithmic_error: 0.0408 - val_loss: 8.5116 - val_mean_absolute_error: 2.8356 - val_mean_squared_error: 8.5117 - val_mean_squared_logarithmic_error: 0.2991
# Epoch 86/100
# 300/300 [==============================] - 0s 137us/sample - loss: 1.6615 - mean_absolute_error: 1.0486 - mean_squared_error: 1.6615 - mean_squared_logarithmic_error: 0.0365 - val_loss: 9.7401 - val_mean_absolute_error: 3.0403 - val_mean_squared_error: 9.7401 - val_mean_squared_logarithmic_error: 0.3630
# Epoch 87/100
# 300/300 [==============================] - 0s 137us/sample - loss: 1.7296 - mean_absolute_error: 1.0371 - mean_squared_error: 1.7296 - mean_squared_logarithmic_error: 0.0373 - val_loss: 9.6391 - val_mean_absolute_error: 3.0262 - val_mean_squared_error: 9.6391 - val_mean_squared_logarithmic_error: 0.3560
# Epoch 88/100
# 300/300 [==============================] - 0s 133us/sample - loss: 1.6688 - mean_absolute_error: 1.0179 - mean_squared_error: 1.6688 - mean_squared_logarithmic_error: 0.0348 - val_loss: 9.5251 - val_mean_absolute_error: 3.0084 - val_mean_squared_error: 9.5251 - val_mean_squared_logarithmic_error: 0.3497
# Epoch 89/100
# 300/300 [==============================] - 0s 140us/sample - loss: 1.6119 - mean_absolute_error: 0.9966 - mean_squared_error: 1.6119 - mean_squared_logarithmic_error: 0.0346 - val_loss: 9.0297 - val_mean_absolute_error: 2.9262 - val_mean_squared_error: 9.0297 - val_mean_squared_logarithmic_error: 0.3235
# Epoch 90/100
# 300/300 [==============================] - 0s 140us/sample - loss: 1.5985 - mean_absolute_error: 0.9770 - mean_squared_error: 1.5985 - mean_squared_logarithmic_error: 0.0351 - val_loss: 9.1432 - val_mean_absolute_error: 2.9453 - val_mean_squared_error: 9.1432 - val_mean_squared_logarithmic_error: 0.3281
# Epoch 91/100
# 300/300 [==============================] - 0s 143us/sample - loss: 1.7920 - mean_absolute_error: 1.0868 - mean_squared_error: 1.7920 - mean_squared_logarithmic_error: 0.0382 - val_loss: 9.7261 - val_mean_absolute_error: 3.0413 - val_mean_squared_error: 9.7261 - val_mean_squared_logarithmic_error: 0.3590
# Epoch 92/100
# 300/300 [==============================] - 0s 127us/sample - loss: 1.8015 - mean_absolute_error: 1.0559 - mean_squared_error: 1.8015 - mean_squared_logarithmic_error: 0.0387 - val_loss: 10.0318 - val_mean_absolute_error: 3.0914 - val_mean_squared_error: 10.0318 - val_mean_squared_logarithmic_error: 0.3752
# Epoch 93/100
# 300/300 [==============================] - 0s 133us/sample - loss: 1.7505 - mean_absolute_error: 1.0771 - mean_squared_error: 1.7505 - mean_squared_logarithmic_error: 0.0389 - val_loss: 9.3381 - val_mean_absolute_error: 2.9764 - val_mean_squared_error: 9.3381 - val_mean_squared_logarithmic_error: 0.3408
# Epoch 94/100
# 300/300 [==============================] - 0s 127us/sample - loss: 2.0013 - mean_absolute_error: 1.1416 - mean_squared_error: 2.0013 - mean_squared_logarithmic_error: 0.0427 - val_loss: 8.1418 - val_mean_absolute_error: 2.7703 - val_mean_squared_error: 8.1418 - val_mean_squared_logarithmic_error: 0.2810
# Epoch 95/100
# 300/300 [==============================] - 0s 127us/sample - loss: 1.4876 - mean_absolute_error: 0.9419 - mean_squared_error: 1.4876 - mean_squared_logarithmic_error: 0.0311 - val_loss: 10.0560 - val_mean_absolute_error: 3.0921 - val_mean_squared_error: 10.0560 - val_mean_squared_logarithmic_error: 0.3801
# Epoch 96/100
# 300/300 [==============================] - 0s 133us/sample - loss: 1.7705 - mean_absolute_error: 1.0602 - mean_squared_error: 1.7705 - mean_squared_logarithmic_error: 0.0388 - val_loss: 9.4337 - val_mean_absolute_error: 2.9888 - val_mean_squared_error: 9.4337 - val_mean_squared_logarithmic_error: 0.3483
# Epoch 97/100
# 300/300 [==============================] - 0s 140us/sample - loss: 1.6784 - mean_absolute_error: 1.0272 - mean_squared_error: 1.6784 - mean_squared_logarithmic_error: 0.0365 - val_loss: 9.2999 - val_mean_absolute_error: 2.9691 - val_mean_squared_error: 9.2999 - val_mean_squared_logarithmic_error: 0.3397
# Epoch 98/100
# 300/300 [==============================] - 0s 153us/sample - loss: 1.4756 - mean_absolute_error: 0.9658 - mean_squared_error: 1.4756 - mean_squared_logarithmic_error: 0.0317 - val_loss: 10.1500 - val_mean_absolute_error: 3.1118 - val_mean_squared_error: 10.1500 - val_mean_squared_logarithmic_error: 0.3804
# Epoch 99/100
# 300/300 [==============================] - 0s 150us/sample - loss: 1.8193 - mean_absolute_error: 1.0595 - mean_squared_error: 1.8193 - mean_squared_logarithmic_error: 0.0400 - val_loss: 7.8855 - val_mean_absolute_error: 2.7240 - val_mean_squared_error: 7.8855 - val_mean_squared_logarithmic_error: 0.2691
# Epoch 100/100
# 300/300 [==============================] - 0s 147us/sample - loss: 1.6374 - mean_absolute_error: 1.0160 - mean_squared_error: 1.6374 - mean_squared_logarithmic_error: 0.0358 - val_loss: 9.9593 - val_mean_absolute_error: 3.0800 - val_mean_squared_error: 9.9593 - val_mean_squared_logarithmic_error: 0.3706

# %%
pyplot.title('Loss - Mean Squared Error')
pyplot.plot(history2.history['loss'], label='train')
pyplot.plot(history2.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
def plot_results(X, Y, Y_predict, plot_name):
    pyplot.figure()
    pyplot.scatter(Y, Y_predict)
    pyplot.grid()
    pyplot.xlabel("Real Qualities")
    pyplot.ylabel("Predictions Qualities")
    pyplot.figure()
    pyplot.scatter(X['alcohol'], Y, label="values")
    pyplot.plot(X['alcohol'], Y_predict, color="red", label="model")
    pyplot.grid()
    pyplot.xlabel("alcohol")
    pyplot.ylabel("quality")
    pyplot.legend()
test_predictions = model2.predict(x_v).flatten()
plot_results(x_v, y_v, test_predictions, "results_nn.png")

# %% [markdown]
# Compare the results:

# %%
pyplot.title('Loss/Mean Squared Error')
pyplot.plot(history.history['loss'], 'r', label='train_1',)
pyplot.plot(history.history['val_loss'], 'b', label='validation_1')
pyplot.plot(history2.history['loss'], 'm', label='train_2')
pyplot.plot(history2.history['val_loss'], 'k', label='validation_2')
pyplot.legend()
pyplot.show()

# %%
pyplot.title('Loss/Mean Squared Error')
pyplot.plot(history.history['loss'][80:100], 'r', label='train_1',)
pyplot.plot(history.history['val_loss'][80:100], 'b', label='validation_1')
pyplot.plot(history2.history['loss'][80:100], 'm', label='train_2')
pyplot.plot(history2.history['val_loss'][80:100], 'k', label='validation_2')
pyplot.legend()
pyplot.show()

# %% [markdown]
# Looks like using multi variable, we have a better model.

# %% [markdown]
# Prediction:

# %%
test_predictions = model2.predict(x_v).flatten()

predicted_loss = np.abs(y_v.values-test_predictions)/y_v.describe().transpose()['mean']

print("\nReal Qualities:\n", y_v.values[0:4])
print("\nPredicted Qualities:\n", test_predictions[0:4])
print("\nLoss:\n", predicted_loss[0:4])
print("\nMean Loss:", np.mean(predicted_loss))
# Out:
# Real Qualities:
#  [5 7 6 5]
#
# Predicted Qualities:
#  [2.7052362 2.8606114 2.411775  2.5912948]
#
# Loss:
#  [0.3954695  0.71336402 0.61837889 0.41510566]
#
# Mean Loss: 0.5307974339612758

# %% [markdown]
# Plot the difference

# %%
test_predictions = model2.predict(x_v).flatten()
pyplot.plot(range(len(predicted_loss)), predicted_loss)
